# %%
# %matplotlib nbagg

import cv2

import numpy as np
from matplotlib import pyplot as plt

capture = cv2.VideoCapture(0)
n=0
plt.ion()

while(True):
    ret, frame = capture.read()
    mean = frame.mean()
    plt.plot(n, mean, marker="o", color="red")
    plt.show
    print('mean',mean)
    cv2.imshow('frame',frame)
    n=n+1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# <img src="data:image/png;base64,..." width="639.430879990485">
# mean 106.88418077256945
# mean 106.16914171006944
# mean 105.00662217881944
# mean 105.00662217881944
# mean 103.31601671006945
# mean 103.31601671006945
# mean 100.61805772569444
# mean 100.61805772569444
# mean 98.17635416666667
# mean 98.17635416666667
# mean 96.69528428819444
# mean 96.69528428819444
# mean 95.58674370659722
# mean 95.58674370659722
# mean 95.075947265625
# mean 95.075947265625
# mean 95.06021484375
# mean 95.06021484375
# mean 94.75101671006945
# mean 95.06235568576389
# mean 95.06235568576389
# mean 94.97874674479166
# mean 94.97874674479166
# mean 94.782421875
# mean 94.782421875
# mean 95.14563693576389
# mean 95.14563693576389
# mean 95.01683919270833
# mean 95.01683919270833
# mean 95.296162109375
# mean 95.296162109375
# mean 95.20439670138889
# mean 95.20439670138889
# mean 94.90511501736111
# mean 94.90511501736111
# mean 94.98401041666666
# mean 94.98401041666666
# mean 94.78845160590278
# ...
